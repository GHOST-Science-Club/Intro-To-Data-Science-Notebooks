# %% [markdown]
# <center>
#     <h2>
#         Best knowledge source 😍 -
#         <a href="https://wesmckinney.com/book/pandas-basics">here</a>
#     </h2>
# </center>
#
# ---

# %% [markdown]
# # Library import

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading files
#
# Source: <a href="https://www.kaggle.com/datasets/brendan45774/test-file">Brenda N - Titanic - Kaggle</a>

# %%
data = pd.read_csv("./data/titanic.csv")
data.head() # tail or sample

# %% [markdown]
# # Reading data from DataFrame

# %%
data["Age"]

# %% [markdown]
# #### `.loc`

# %%
data.loc[5]
# data.loc[5:10]

# %%
data.loc[5:10, ["Name", "Age"]]

# %% [markdown]
# #### `.iloc`

# %%
data.iloc[5]

# %%
data.iloc[:, 3:6]

# %% [markdown]
# # Basic informatin about dataset

# %% [markdown]
# #### `.info`

# %%
data.info()

# %% [markdown]
# #### `.describe`

# %%
data.describe()

# %%
data['Age'].mean()
# Out:
# 30.272590361445783

# %% [markdown]
# #### `.unique`

# %%
data['Pclass'].unique()

# %% [markdown]
# # Droping and filling empty cells

# %% [markdown]
# ### `.dropna`

# %%
data.sample(5)

# %%
data_copy = data.dropna(subset=["Age"])
# data_copy = data.dropna(subset=["Age", "Fare"])
data_copy

# %% [markdown]
# ### `.dropna` inplace

# %%
data.dropna(subset=["Age"], inplace=True)
len(data)

# %% [markdown]
# ### `.fillna`

# %%
data['Cabin'].fillna("not known", inplace=True)
data.head()

# %% [markdown]
# # Droping rows and columns

# %% [markdown]
# #### Drop rows

# %%
data.drop(0).head()

# %% [markdown]
# #### Drop columns

# %%
data.drop("PassengerId", axis=1).head()

# %% [markdown]
# # Filtering

# %%
data[data['Age'] > 30].head()

# %%
data[data["Sex"] == "female"].head()

# %% [markdown]
# #### Filtering with multiple conditions

# %%
data_copy = data[(data['Age'] > 30) & (data['Sex'] == "female")]
# data_copy = data[(data['Age'] > 30) | (data['Sex'] == "female")]
print(len(data_copy))
data_copy.head()

# %% [markdown]
# #### `.isnull()` and `.notnull()`

# %%
data = pd.read_csv("./data/titanic.csv")

# data[data['Age'].notnull()].head()
data[data['Age'].isnull()].head()

# %% [markdown]
# #### `.isin`

# %%
data[data['Pclass'].isin([1, 2])].head()

# %% [markdown]
# # Sorting

# %% [markdown]
# #### `.sort_values`

# %%
data.sort_values("Age")

# %% [markdown]
# #### `.sort_index`

# %%
data.sort_index()

# %% [markdown]
# #### `.reset_index`

# %%
data.sort_values("Age", inplace=True)
data.reset_index(drop=True, inplace=True)
data.head()

# %% [markdown]
# # Aggregation

# %%
data = pd.read_csv("./data/titanic.csv")

# %% [markdown]
# #### `.mean`, `.count`, `.sum`, etc.

# %%
data[["Sex", "Age"]].groupby(["Sex"]).mean()

# %%
data[["Sex", "PassengerId"]].groupby("Sex").count()

# %%
data[["Sex", "Fare"]].groupby("Sex").sum()

# %% [markdown]
# #### `.agg`

# %%
data[["Sex", "Fare"]].groupby("Sex").agg(["sum", "mean", "count"])
